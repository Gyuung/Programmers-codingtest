# %% [markdown]
# 문제 설명
# 가로 길이가 Wcm, 세로 길이가 Hcm인 직사각형 종이가 있습니다. 종이에는 가로, 세로 방향과 평행하게 격자 형태로 선이 그어져 있으며, 모든 격자칸은 1cm x 1cm 크기입니다. 이 종이를 격자 선을 따라 1cm × 1cm의 정사각형으로 잘라 사용할 예정이었는데, 누군가가 이 종이를 대각선 꼭지점 2개를 잇는 방향으로 잘라 놓았습니다. 그러므로 현재 직사각형 종이는 크기가 같은 직각삼각형 2개로 나누어진 상태입니다. 새로운 종이를 구할 수 없는 상태이기 때문에, 이 종이에서 원래 종이의 가로, 세로 방향과 평행하게 1cm × 1cm로 잘라 사용할 수 있는 만큼만 사용하기로 하였습니다.
# 가로의 길이 W와 세로의 길이 H가 주어질 때, 사용할 수 있는 정사각형의 개수를 구하는 solution 함수를 완성해 주세요.
#
# 제한사항
# W, H : 1억 이하의 자연수
# 입출력 예
# W	H	result
# 8	12	80
# 입출력 예 설명
# 입출력 예 #1
# 가로가 8, 세로가 12인 직사각형을 대각선 방향으로 자르면 총 16개 정사각형을 사용할 수 없게 됩니다. 원래 직사각형에서는 96개의 정사각형을 만들 수 있었으므로, 96 - 16 = 80 을 반환합니다.
#
# 572957326.92.png

# %% [markdown]
# 가로 세로 result defect        이건 무조건 코드 문제가 아니라 수학문제라고 생각한다 수학규칙이 존재하기 때문에 코드작성을 하라는거다.
#
#  8    12    80     16           가로 세로가 반대로 바뀌어도 어짜피 반으로 접는것 이기 때문에 결과는 똑같음 그것을 이용해보자
#
#  8    12                        를 두배 줄여보자
#
#  4     6    16      8
#
#  2     3     2      4                    ![image.png](attachment:image.png)
#
#  여기서 나온 결론 가로 세로가 증가해도 결함 수 만 2배씩 증가함 왜냐하면 두배로 증가해도 그어지는 선쪽 만 두배로 늘어나기 때문에
#  그러면 결론은 가로 세로를 가장 낮은 숫자로 나눈다음에 결함수를 구하고 그만큼 곱해준다.
#  두 수가 가장 낮은 수가 되려면 서로소 를 만들어야 한다.(두 수의 최대공약수가 1이 되게 만드는것) 그러면 가로와 세로에 최대공약수로 나눠준다음 결함수를 구해서 다시 그 숫자 만큼 곱한다. 하지만 여기서 다시 그 숫자 만큼 곱해주는 것은 아마 서로소 로 만들어 줬을때 나눠주었던 최대공약수 일것이다. 당연한 것이지만 그렇다면 규칙은 존재한다.
#
#  서로소 일때의 규칙을 찾아서 적용하면 가로랑 세로가 몇이 되든 같아진다. 생각해보니 가로 세로가 반대로 바뀌어도 결과는 똑같다는 것은 가로랑 세로가 공통으로 가져가는 규칙을 적용해야 한다는것 음...
#  알았다!!!!! 당연한 것이었는데 너무 오래 생각했다. 가로 세로를 서로소 로 만들었을때 나눠어준 값만큼 결함수가 그만큼 줄어들었다는것은 그만큼 나눠줬으니 그만큼 최대공약수가 줄었으니 결론은 최대공약수 였다. 이문제는 최대공약수가 힌트네
#  가로 세로 더하고 최대공약수를 빼주면 해결완료네 코드작성시작

# %%
import math

def solution(w,h):
    return (w*h) - (w + h - math.gcd(w,h))

solution(8,12)
# Out:
# 80
